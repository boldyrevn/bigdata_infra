# %%
from pyspark.sql import SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("your_application_name") \
    .master("yarn") \
    .config("spark.submit.deployMode", "client") \
    .config("spark.hadoop.yarn.resourcemanager.address", "dataops-hadoop-mn-1:8032") \
    .config("spark.hadoop.yarn.resourcemanager.scheduler.address", "dataops-hadoop-mn-1:8030") \
    .config("spark.hadoop.yarn.resourcemanager.resource-tracker.address", "dataops-hadoop-mn-1:8031") \
    .config("spark.hadoop.yarn.resourcemanager.webapp.address", "dataops-hadoop-mn-1:8088") \
    .config("spark.yarn.historyServer.address", "dataops-hadoop-mn-2:18080") \
    .config("spark.eventLog.enabled", "true") \
    .config("spark.sql.shuffle.partitions", "200") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "8g") \
    .config("spark.executor.cores", "4") \
    .config("spark.executor.instances", "10") \
    .config("spark.dynamicAllocation.enabled", "false") \
    .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
    .config("spark.sql.adaptive.enabled", "true") \
    .getOrCreate()
# Out:
# 2025-07-01 20:34:18 WARN  spark.sql.SparkSession:73 - Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
type(spark)
# Out:
# pyspark.sql.session.SparkSession

# %%
spark = SparkSession.builder \
    .config("master", "yarn") \
    .appName("new_spark") \
    .getOrCreate()
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/opt/jupyterhub/lib/python3.9/site-packages/pyspark/jars/log4j-slf4j-impl-2.17.2.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hadoop/lib/slf4j-log4j12-1.7.25.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]
# Warning: Ignoring non-Spark config property: master
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 2025-07-01 20:32:22 WARN  spark.util.Utils:73 - Service 'sparkDriver' could not bind on port 40000. Attempting port 40001.
# 2025-07-01 20:32:23 WARN  spark.util.Utils:73 - Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 2025-07-01 20:32:23 WARN  deploy.yarn.Client:73 - Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# 2025-07-01 20:32:29 WARN  spark.util.Utils:73 - Service 'org.apache.spark.network.netty.NettyBlockTransferService' could not bind on port 40500. Attempting port 40501.
# 2025-07-01 20:32:30 WARN  scheduler.cluster.YarnSchedulerBackend$YarnSchedulerEndpoint:73 - Attempted to request executors before the AM has registered!

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dataops-hadoop-en-3:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>new_spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Введение

# %%
data = [1, 2, 3, 4, 5]
rdd = spark.sparkContext.parallelize(data)

# %%
rdd
# Out:
# ParallelCollectionRDD[0] at readRDDFromFile at PythonRDD.scala:274

# %%
print(rdd)
# Out:
# ParallelCollectionRDD[0] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd.collect()
# Out:
# [1, 2, 3, 4, 5]

# %%
rdd.repartition(2)
# Out:
# MapPartitionsRDD[5] at coalesce at NativeMethodAccessorImpl.java:0

# %%
rdd
# Out:
# ParallelCollectionRDD[0] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd.repartition(2).collect()
# Out:
# [5, 1, 2, 3, 4]

# %%
rdd_mapped = rdd.map(lambda x: x * 2)

# %%
rdd_mapped
# Out:
# PythonRDD[11] at RDD at PythonRDD.scala:53

# %%
rdd_mapped.collect()
# Out:
# [2, 4, 6, 8, 10]

# %%
rdd_filtered = rdd.filter(lambda x: x % 2 == 0)

# %%
rdd_filtered.collect()
# Out:
# [2, 4]

# %%
grouped = rdd.groupBy(lambda x: "even" if x % 2 == 0 else "odd")

# %%
grouped.collect()
# Out:
# [('odd', <pyspark.resultiterable.ResultIterable at 0x7f2b8d35e940>),
#  ('even', <pyspark.resultiterable.ResultIterable at 0x7f2b8d4a80a0>)]

# %%
print({k: list(v) for k, v in grouped.collect()})
# Out:
# [Stage 8:=============================================>        (167 + 10) / 200]
# {'odd': [1, 3, 5], 'even': [2, 4]}

# %% [markdown]
# # Экшены

# %%
data = rdd.collect()

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
first_2 = rdd.take(3)

# %%
first_2
# Out:
# [1, 2, 3]

# %%
rdd.count()
# Out:
# 5

# %%
sum = rdd.reduce(lambda a, b: a + b)

# %%
sum
# Out:
# 15

# %% [markdown]
# ### Передаем данные на драйвер:
#
# - collect()
# - take()
# - count()
# - бродкаст-переменные

# %%
print(rdd.collect())
# Out:
# [1, 2, 3, 4, 5]

# %%
broadcast_var = spark.sparkContext.broadcast([10, 20, 30, 40, 50])

# %%
rdd_with_broadcast = rdd.map(lambda x: x + broadcast_var.value[0])

# %%
rdd_with_broadcast.collect()
# Out:
# [11, 12, 13, 14, 15]

# %%
from random import randint

# %%
data_ = [randint(1, 15) for _ in range(10)]

# %%
data_
# Out:
# [5, 2, 11, 5, 8, 15, 13, 4, 15, 14]

# %%
rdd_ = spark.sparkContext.parallelize(data_)

# %%
rdd_.collect()
# Out:
# [5, 2, 11, 5, 8, 15, 13, 4, 15, 14]

# %%
rdd_.repartition(5).collect() # шафл
# Out:
# [5, 15, 4, 8, 14, 2, 5, 13, 15, 11]

# %%
rdd_.coalesce(2).collect() # без шафла
# Out:
# [5, 2, 11, 5, 8, 15, 13, 4, 15, 14]

# %%
rdd_.count()
# Out:
# 10

# %%
rdd_.cache()
# Out:
# ParallelCollectionRDD[29] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd_.persist()
# Out:
# ParallelCollectionRDD[29] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd_.unpersist()
# Out:
# ParallelCollectionRDD[29] at readRDDFromFile at PythonRDD.scala:274

# %%
a = rdd_.persist()

# %%
a.count()
# Out:
# 10

# %%
rdd_.count()
# Out:
# 10

# %% [markdown]
# ### Объединение rdd

# %%
rdd1 = spark.sparkContext.parallelize([1, 2, 3]).repartition(1)
rdd2 = spark.sparkContext.parallelize([4, 5, 6]).repartition(1)

# %%
union_rdd = rdd1.union(rdd2)

# %%
union_rdd.collect()
# Out:
# [2, 3, 1, 6, 4, 5]

# %%
rdd_pairs1 = spark.sparkContext.parallelize([(1, "A"), (2, "B"), (3, "C")])
rdd_pairs2 = spark.sparkContext.parallelize([(1, "X"), (2, "Y"), (4, "Z")])

# %%
rdd_pairs1
# Out:
# ParallelCollectionRDD[59] at readRDDFromFile at PythonRDD.scala:274

# %%
rdd_pairs1.collect()
# Out:
# [(1, 'A'), (2, 'B'), (3, 'C')]

# %%
joined_rdd = rdd_pairs1.join(rdd_pairs2)

# %%
joined_rdd.collect()
# Out:
# [(1, ('A', 'X')), (2, ('B', 'Y'))]

# %%
from pyspark.sql.types import *

# %%
rdd_next = spark.sparkContext.parallelize([(1, "Alice"), (2, "Bob"), (3, "Charlie")])

# %%
schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True)
])

# %%
df = spark.createDataFrame(rdd_next, schema)
df.show()
# Out:
# [Stage 46:======================================>                 (51 + 3) / 75]
# +---+-------+
# | id|   name|
# +---+-------+
# |  1|  Alice|
# |  2|    Bob|
# |  3|Charlie|
# +---+-------+

# %%
df.collect()
# Out:
# [Row(id=1, name='Alice'), Row(id=2, name='Bob'), Row(id=3, name='Charlie')]

# %% [markdown]
# ### Работа с JSON

# %%
json_rdd = spark.sparkContext.parallelize([
    '{"id": 1, "name": "Alice"}',
    '{"id": 2, "name": "Bob"}'
])

# %%
df_j = spark.read.json(json_rdd)
df_j.show()
# Out:
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+

# %%
df_j.collect()
# Out:
# [Row(id=1, name='Alice'), Row(id=2, name='Bob')]

# %% [markdown]
# ### WC

# %%
text_rdd = spark.sparkContext.parallelize([
    "Spark is awesome",
    "Spark is fast",
    "Hello Spark"
])

# %%
word_counts = (text_rdd
               .flatMap(lambda line: line.split(" ")) 
               .map(lambda word: (word, 1))           
               .reduceByKey(lambda a, b: a + b))

# %%
word_counts.collect()
# Out:
# [('is', 2), ('awesome', 1), ('Hello', 1), ('Spark', 3), ('fast', 1)]

# %% [markdown]
# ### Вычисление среднего

# %%
salary_data = [("IT", 100), ("HR", 80), ("IT", 120), ("HR", 90)]
rdd = spark.sparkContext.parallelize(salary_data)

# %%
result = (rdd
          .mapValues(lambda x: (x, 1))               
          .reduceByKey(lambda a, b: (a[0]+b[0], a[1]+b[1]))  
          .mapValues(lambda x: x[0]/x[1]))

# %%
result = (rdd
          .mapValues(lambda x: (x, 1)))

# %%
result.collect()
# Out:
# [('IT', (100, 1)), ('HR', (80, 1)), ('IT', (120, 1)), ('HR', (90, 1))]

# %%
result_ = result.reduceByKey(lambda a, b: (a[0]+b[0], a[1]+b[1]))

# %%
result_.collect()
# Out:
# [('IT', (220, 2)), ('HR', (170, 2))]

# %%
result__ = result_.mapValues(lambda x: x[0]/x[1])

# %%
result__.collect()
# Out:
# [('IT', 110.0), ('HR', 85.0)]

# %% [markdown]
# ### flatMap

# %% [markdown]
# разбиение строк на слова

# %%
lines = ["Hello world", "Apache Spark", "PySpark RDD"]
rdd = spark.sparkContext.parallelize(lines)

# %%
words_rdd = rdd.flatMap(lambda line: line.split(" "))

# %%
print(words_rdd.collect())
# Out:
# ['Hello', 'world', 'Apache', 'Spark', 'PySpark', 'RDD']

# %% [markdown]
# ### Развертывание вложенных структур

# %%
data = [("A", [1, 2, 3]), ("B", [4, 5])]
rdd = spark.sparkContext.parallelize(data)

# %%
flattened = rdd.flatMap(lambda x: [(x[0], num) for num in x[1]])

# %%
print(flattened.collect())
# Out:
# [Stage 56:=================================================>    (185 + 3) / 200]
# [('A', 1), ('A', 2), ('A', 3), ('B', 4), ('B', 5)]

# %% [markdown]
# ### Оптимизация

# %%
data = [("A", 10), ("B", 20), ("A", 30), ("B", 40)]
rdd = spark.sparkContext.parallelize(data)

# %%
rdd.collect()
# Out:
# [('A', 10), ('B', 20), ('A', 30), ('B', 40)]

# %%
result = rdd.aggregateByKey(
    (0, 0),                         # Нулевое значение
    lambda acc, val: (acc[0] + val, acc[1] + 1),  # Локальная агрегация
    lambda acc1, acc2: (acc1[0] + acc2[0], acc1[1] + acc2[1]))

# %%
result.collect()
# Out:
# [('A', (40, 2)), ('B', (60, 2))]

# %%
result = rdd.combineByKey(
    lambda value: (value, 1, value),                  # Создаем аккумулятор
    lambda acc, value: (acc[0] + value, acc[1] + 1, max(acc[2], value)),
    lambda acc1, acc2: (acc1[0] + acc2[0], acc1[1] + acc2[1], max(acc1[2], acc2[2])))

print(result.collect())
# Out:
# [('A', (40, 2, 30)), ('B', (60, 2, 40))]
